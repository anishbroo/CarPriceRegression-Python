# %% [markdown]
# #### &emsp;`why to use?`
# - &emsp;&emsp; can visualize data using different plots.
# - &emsp;&emsp; understanding the data becomes easier.
# - &emsp;&emsp; Mostly written in python. For platform compatibility, C, Objectibe-C and Javascript are used.

# %% [markdown]
# #### &emsp; `Package installation`
# ```python
#     # Type
#     pip install matplotlib
#     # in command prompt after activating the environment.
# ```

# %%
# import in file to use its features.
import matplotlib
import matplotlib.pyplot as plt

# check version
print(matplotlib.__version__)
# Out:
# 3.7.0

# %% [markdown]
# #### `Different Types of Plots`
# - Line Plot
# - Scatter Plot
# - Bar Plot
# - Pie Chart

# %%
# import the dependency
import numpy as np

# %% [markdown]
# #### `Draw line using coordinate values`

# %%
# Plot line from point(2, 3) to (3, 5)
import matplotlib.pyplot as plt

# Create two numpy arrays: one with x-coordinate values 
# and other with y-coordinate values
xpoints = np.array([2, 5])
ypoints = np.array([3, 10])

# use plot() method in matplotlib module 
# plot takes two arguments: first-array containing x-coordinates
# second-array containing y-coordinates
plt.plot(xpoints, ypoints)

# show() method to visualize the plot done
plt.show()

# %%
# Plot line from point(2, 3) to (3, 5) to (4, 6) to (5, 3)
import matplotlib.pyplot as plt

xpoints = np.array([2, 3, 4, 5])
ypoints = np.array([3, 5, 6, 3])

plt.plot(xpoints, ypoints)
plt.show()

# %%
# Plotting without line
# third argument is marker
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
# Plotting without line
# third argument is marker
# Highlight the points using 'marker' argument.
plt.plot(xpoints, ypoints, marker='o')
plt.show()

# %% [markdown]
# ##### `List of Markers`
# - 'd' - Diamond
#
# - 'D' - Diamond (bold)
# - 'h' - Hexagon
# - 'H' - Hexagon (bold)
# - 's' - Square
# - 'p' - Pentagon
# - 'x' - X
# - 'X' - X (bold)
# - 'v' - Triangle facing down
# - '^' - Triangle facing up
# - '<' - Triangle facing left
# - '>' - Triangle facing right
# - '.' - Point
# - 'o' - Circle
# - '*' - Star
# - '+' - Plus
# - 'P' - Plus (bold)
# - '|' - Vline
# - '_' - Hline

# %% [markdown]
# #### `Format the line and markers with 'fmt'`
# ```python
#     # syntax
#     marker|line|color
# ```

# %%
plt.plot(xpoints, ypoints, 's:g')
plt.show()

# %% [markdown]
# #### `List of Line Types`
# - '-'  &emsp;&emsp;&ensp; Solid line
# - ':'  &emsp;&emsp;&ensp; Dotted line
# - '--' &emsp;&emsp; Dashed line
# - '-.' &emsp;&emsp; Dashed/dotted line

# %% [markdown]
# #### `List of colors`
# - 'r' &emsp;&emsp;&ensp;Red
# - 'g' &emsp;&emsp;	Green
# - 'b' &emsp;&emsp;	Blue
# - 'c' &emsp;&emsp;	Cyan
# - 'm' &emsp;&emsp;Magenta
# - 'y' &emsp;&emsp;	Yellow
# - 'k' &emsp;&emsp;	Black
# - 'w' &emsp;&emsp;	White

# %% [markdown]
# #### `Size of the marker with 'ms' argument`

# %%
plt.plot(xpoints, ypoints, 's:g', ms=10)
plt.show()

# %% [markdown]
# #### `Color of edge of marker with 'mec' argument`

# %%
plt.plot(xpoints, ypoints, 's:g', ms=10, mec='r')
plt.show()

# %% [markdown]
# #### `Color of face of marker with 'mfc' argument`

# %%
plt.plot(xpoints, ypoints, 's:g', ms=10, mec='r', mfc='k')
plt.show()

# %% [markdown]
# #### `Hexadecimal values for colors`

# %%
plt.plot(xpoints, ypoints, 's:g', ms=10, mec='r', mfc='#5CFA50')
plt.show()

# %% [markdown]
# #### `Control lines`
# - style using 'ls' argument
# - color using 'color' or 'c' argument
# - line width using 'linewidth' argument

# %%
plt.plot(xpoints, ypoints, ls=':', c='g', linewidth='2')
plt.show()

# %% [markdown]
# #### `Plot multiple lines`

# %%
xpoints_1, ypoints_1 = xpoints+1, ypoints+1
plt.plot(xpoints, ypoints)
plt.plot(xpoints_1, ypoints_1)
plt.show()

# %%
xpoints_1, ypoints_1 = xpoints+1, ypoints+1

plt.plot(xpoints, ypoints, xpoints_1, ypoints_1)
plt.show()

# %% [markdown]
# #### `Labels and Title`

# %%
plt.plot(xpoints, ypoints)
plt.xlabel('x-label')
plt.ylabel('y-label')
plt.title('Title')
plt.show()

# %% [markdown]
# #### `Font Properties for Title and Labels`

# %%
font1 = {'family':'serif','color':'blue','size':10}
font2 = {'family':'serif','color':'darkred','size':20}

plt.plot(xpoints, ypoints)
plt.xlabel('x-label', fontdict=font1)
plt.ylabel('y-label', fontdict=font1)
plt.title('Title', fontdict=font2)
plt.show()

# %% [markdown]
# #### `Position the Title`
# - Place the title in 'left', 'right', and 'center' using `loc` attribute

# %%
plt.plot(xpoints, ypoints)
plt.xlabel('x-label')
plt.ylabel('y-label')
plt.title('Title', loc='center')
plt.show()

# %% [markdown]
# #### `Adding grid to the graph`

# %%
plt.plot(xpoints, ypoints)
plt.xlabel('x-label')
plt.ylabel('y-label')
plt.title('Title')
plt.grid()
plt.show()

# %% [markdown]
# #### `Choose which grid lines to display`

# %%
plt.plot(xpoints, ypoints)
plt.xlabel('x-label')
plt.ylabel('y-label')
plt.title('Title')
plt.grid(axis='y')
plt.show()

# %% [markdown]
# #### `line properties for grid`
# - Attributes: color, linestyle, linewidth

# %%
plt.plot(xpoints, ypoints)

plt.grid(color='green', linestyle='--', linewidth=2)
plt.show()

# %% [markdown]
# #### `Default x-values`

# %%
# if no x-coordinates are given then 1, 2, 3, 4, ... are default x-values
# and ranges upto the length of array holding y-values. 

y_vals = np.array([2, 4, 0, 3, 9, 3])

plt.plot(y_vals)
plt.show()

# %% [markdown]
# ### `Subplot`
# - Multiple sub plots in single plot using `subplot()`
# - takes 3 arguments:<br/>
#     &emsp;first - number of rows<br/>
#     &emsp;second - number of columns<br/>
#     &emsp;third - plot number

# %%
nrows = 1
ncols = 2

plt.subplot(nrows, ncols, 1)
x = np.array([1, 2, 3, 5])
y = np.array([3, 1, 9, 6])
plt.plot(x, y)

plt.subplot(nrows, ncols, 2)
x = np.array([2, 4, 8, 9])
y = np.array([0, 2, 1, 5])
plt.plot(x, y)

# %%
nrows = 2
ncols = 2

plt.subplot(nrows, ncols, 1)
x = np.array([1, 2, 3, 5])
y = np.array([3, 1, 9, 6])
plt.plot(x, y)
plt.title("first")

plt.subplot(nrows, ncols, 2)
x = np.array([2, 4, 8, 9])
y = np.array([0, 2, 1, 5])
plt.plot(x, y)
plt.title("second")

plt.subplot(nrows, ncols, 3)
x = np.array([1, 2, 3, 5])
y = np.array([3, 1, 9, 6])
plt.plot(x, y)
plt.title("third")

plt.subplot(nrows, ncols, 4)
x = np.array([2, 4, 8, 9])
y = np.array([0, 2, 1, 5])
plt.plot(x, y)
plt.title("fourth")

plt.suptitle("Title")

# %% [markdown]
# #### `Scatter Plot`
# - one dot for each observation
# - requires two arrays of equal length: <br/>
# &emsp; one for x-axis<br/>
# &emsp; other for y-axis

# %%
# scatter plot 
x = np.array([1, 2, 3, 4, 5, 6, 6, 7, 8, 9])
y = np.array([10, 2, 4, 5, 2, 8, 4, 1, 6, 11])

plt.scatter(x, y)

# %%
# data for scatter plot
x = np.array([1, 2, 3, 4, 5, 6, 6, 7, 8, 9])
y = np.array([10, 2, 4, 5, 2, 8, 4, 1, 6, 11])
x1 = x + 1
y1 = y - 1

# %%
# draw two plots in same figure
plt.scatter(x, y)
plt.scatter(x1, y1)

# %%
# Adding custom colours to the plot
plt.scatter(x, y, color='g')
plt.scatter(x1, y1, color='k')

# %%
# adding label to plot
# Adding custom colours to the plot
plt.scatter(x, y, color='g', label='green color')
plt.scatter(x1, y1, color='k', label="black color")
plt.legend()

# %%
# Bar chart
x = np.array(["car", "bike", 'truck', 'bicycle'])
y = np.array([3, 8, 4, 6])

plt.bar(x,y)

# change color of bars 
# plt.bar(x,y,  color='g')

# width of the bar
# plt.bar(x, y, width=0.5)

# %%
# Horizontal Bar chart
x = np.array(["car", "bike", 'truck', 'bicycle'])
y = np.array([3, 8, 4, 6])

plt.barh(x,y)

# height of bars 
plt.barh(x, y, height=0.2)

# %% [markdown]
# ## `Histogram`
# - shows frequency distribution
# - shows number of observation in particular interval

# %%
x = np.random.normal(size=100) * 100
print(len(x))
print(x)

# %%
plt.hist(x)

# %% [markdown]
# #### `Pie-chart`

# %%
x = np.array([35, 25, 25, 15])

plt.pie(x)

# %% [markdown]
# Here, each portion is calculated using formula: `element/sum_of_all_elements`

# %%
# Add labels to each portion of pie-chart
x = np.array([35, 25, 25, 15])
labels = ['car', 'bike', 'truck', 'bicycle']

plt.pie(x, labels=labels)
# startangle

# %%
# explode the portion of pie-chart
x = np.array([35, 25, 25, 15])
labels = ['car', 'bike', 'truck', 'bicycle']
explodes = [0.1, 0, 0, 0]

plt.pie(x, labels=labels, explode=explodes)
# legend
